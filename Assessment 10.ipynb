# %%
import pandas as pd
import seaborn as sns

# %%
ds = pd.read_csv('Assignment 4v2.csv', sep=',')
ds.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
dsCorrelations = ds.corr()
dsCorrelations.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_113a5_row0_col0, #T_113a5_row1_col1, #T_113a5_row2_col2, #T_113a5_row3_col3, #T_113a5_row4_col4, #T_113a5_row5_col5, #T_113a5_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_113a5_row0_col1, #T_113a5_row0_col2, #T_113a5_row0_col5, #T_113a5_row0_col6, #T_113a5_row1_col0, #T_113a5_row2_col0, #T_113a5_row5_col0, #T_113a5_row6_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_113a5_row0_col3, #T_113a5_row0_col4, #T_113a5_row3_col0, #T_113a5_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_113a5_row1_col2, #T_113a5_row2_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_113a5_row1_col3, #T_113a5_row3_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_113a5_row1_col4, #T_113a5_row4_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_113a5_row1_col5, #T_113a5_row5_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_113a5_row1_col6, #T_113a5_row6_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_113a5_row2_col3, #T_113a5_row3_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_113a5_row2_col4, #T_113a5_row4_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_113a5_row2_col5, #T_113a5_row5_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_113a5_row2_col6, #T_113a5_row6_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_113a5_row3_col4, #T_113a5_row4_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_113a5_row3_col5, #T_113a5_row5_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_113a5_row3_col6, #T_113a5_row4_col6, #T_113a5_row6_col3, #T_113a5_row6_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_113a5_row4_col5, #T_113a5_row5_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_113a5_row5_col6, #T_113a5_row6_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_113a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_113a5_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_113a5_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_113a5_level0_col2" class="col_heading level0 col2" >hypertension</th>
#       <th id="T_113a5_level0_col3" class="col_heading level0 col3" >heart_disease</th>
#       <th id="T_113a5_level0_col4" class="col_heading level0 col4" >avg_glucose_level</th>
#       <th id="T_113a5_level0_col5" class="col_heading level0 col5" >bmi</th>
#       <th id="T_113a5_level0_col6" class="col_heading level0 col6" >stroke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_113a5_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_113a5_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_113a5_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_113a5_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_113a5_row0_col3" class="data row0 col3" >-0.00</td>
#       <td id="T_113a5_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_113a5_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_113a5_row0_col6" class="data row0 col6" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_113a5_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_113a5_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_113a5_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_113a5_row1_col2" class="data row1 col2" >0.28</td>
#       <td id="T_113a5_row1_col3" class="data row1 col3" >0.26</td>
#       <td id="T_113a5_row1_col4" class="data row1 col4" >0.24</td>
#       <td id="T_113a5_row1_col5" class="data row1 col5" >0.33</td>
#       <td id="T_113a5_row1_col6" class="data row1 col6" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_113a5_level0_row2" class="row_heading level0 row2" >hypertension</th>
#       <td id="T_113a5_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_113a5_row2_col1" class="data row2 col1" >0.28</td>
#       <td id="T_113a5_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_113a5_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T_113a5_row2_col4" class="data row2 col4" >0.17</td>
#       <td id="T_113a5_row2_col5" class="data row2 col5" >0.17</td>
#       <td id="T_113a5_row2_col6" class="data row2 col6" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_113a5_level0_row3" class="row_heading level0 row3" >heart_disease</th>
#       <td id="T_113a5_row3_col0" class="data row3 col0" >-0.00</td>
#       <td id="T_113a5_row3_col1" class="data row3 col1" >0.26</td>
#       <td id="T_113a5_row3_col2" class="data row3 col2" >0.11</td>
#       <td id="T_113a5_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_113a5_row3_col4" class="data row3 col4" >0.16</td>
#       <td id="T_113a5_row3_col5" class="data row3 col5" >0.04</td>
#       <td id="T_113a5_row3_col6" class="data row3 col6" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_113a5_level0_row4" class="row_heading level0 row4" >avg_glucose_level</th>
#       <td id="T_113a5_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_113a5_row4_col1" class="data row4 col1" >0.24</td>
#       <td id="T_113a5_row4_col2" class="data row4 col2" >0.17</td>
#       <td id="T_113a5_row4_col3" class="data row4 col3" >0.16</td>
#       <td id="T_113a5_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_113a5_row4_col5" class="data row4 col5" >0.18</td>
#       <td id="T_113a5_row4_col6" class="data row4 col6" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_113a5_level0_row5" class="row_heading level0 row5" >bmi</th>
#       <td id="T_113a5_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_113a5_row5_col1" class="data row5 col1" >0.33</td>
#       <td id="T_113a5_row5_col2" class="data row5 col2" >0.17</td>
#       <td id="T_113a5_row5_col3" class="data row5 col3" >0.04</td>
#       <td id="T_113a5_row5_col4" class="data row5 col4" >0.18</td>
#       <td id="T_113a5_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_113a5_row5_col6" class="data row5 col6" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_113a5_level0_row6" class="row_heading level0 row6" >stroke</th>
#       <td id="T_113a5_row6_col0" class="data row6 col0" >0.01</td>
#       <td id="T_113a5_row6_col1" class="data row6 col1" >0.25</td>
#       <td id="T_113a5_row6_col2" class="data row6 col2" >0.13</td>
#       <td id="T_113a5_row6_col3" class="data row6 col3" >0.13</td>
#       <td id="T_113a5_row6_col4" class="data row6 col4" >0.13</td>
#       <td id="T_113a5_row6_col5" class="data row6 col5" >0.04</td>
#       <td id="T_113a5_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# (De correlations tussen 'id' en andere waardes kunnen logischer wijs buiten beschouwing gelaten worden)
#
# Uit bovenstaande tabel is te concluderen dat er in deze dataset niet echt sprake is van sterke corrrelations. De sterkste correlation is tussen de waardes van 'bmi' en 'age'. De zwakste correlation is tussen de waardes van 'hypertension' en 'heart_disease'.
#
# Hieruit is te concluderen dat de verschillende waardes binnen deze dataset wel enige samenhang hebben.
#
# Persoonlijk had ik duidelijkere correlations verwacht. Ik had niet verwacht dat de correlation tussen 'bmi' en 'age' het sterkste was van allemaal. Eerder had ik verwacht dat de correlation tussen bijvoorbeeld 'hypertension' of 'heart_disease' samen met 'stroke' sterker was omdat dit in mijn ogen een mogelijke oorzaken kunnen zijn voor een stroke.
#
# Een nadeel van deze dataset is dat een aantal waardes enkel de waarde 0 en 1 bevatten, hierdoor krijg je op bijvoorbeeld 'heart disease' en 'stroke' een zeer onduidelijke scatterplot.

# %%
ds.plot(kind='scatter', x='bmi', y='age')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='age'>

# %%
ds.plot(kind='scatter', x='avg_glucose_level', y='bmi')
# Out:
# <AxesSubplot:xlabel='avg_glucose_level', ylabel='bmi'>
